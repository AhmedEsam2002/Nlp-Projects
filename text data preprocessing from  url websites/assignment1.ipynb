# %% [markdown]
# import libirarys

# %%
import requests
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import nltk
import nltk
nltk.download('omw-1.4')

# Ensure necessary NLTK resources are downloaded
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ahmed\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\ahmed\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ahmed\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\ahmed\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
#  extract text from url

# %%
# URL of the webpage you want to extract text from
url = "https://alfaroukroute.github.io/Mealify/"

# Send a GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Use BeautifulSoup to parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Extract text from the BeautifulSoup object
    text = soup.get_text(separator=' ', strip=True)
    
    print(text)
else:
    print(f"Failed to retrieve content from {url}, status code: {response.status_code}")
# Out:
# Mealify Mealify Home Chefs Gallery Contact Enjoy Your Healthy Delicious Food Sed autem laudantium dolores. Voluptatem itaque ea consequatur
#             eveniet. Eum quas beatae cumque eum quaerat. Book a Table Watch a Video CHEFS Our Proffesional Chefs Walter White Master Chef Velit aut quia fugit et et. Dolorum ea voluptate vel tempore
#                 tenetur ipsa quae aut. Ipsum exercitationem iure minima enim
#                 corporis et voluptate. Sarah Jhonson Patissier Quo esse repellendus quia id. Est eum et accusantium pariatur
#                 fugit nihil minima suscipit corporis. Voluptate sed quas
#                 reiciendis animi neque sapiente. William Anderson Cook Vero omnis enim consequatur. Voluptas consectetur unde qui
#                 molestiae deserunt. Voluptates enim aut architecto porro
#                 aspernatur molestiae modi. gallery Check Our Gallery Pizza Hawaiian pizza with ham and pineapple Levitation pizza Levitation pizza on black background. Beef steaks Tasty beef steaks flying above cast iron grate with fire flames. Frittata Frittata or potato pie in a ceramic plate Burger grass fed bison hamburger with chips & beer Crispy Fried Chicken Golden brown chicken legs with a crunchy coating and juicy meat Lyulya kebab Tender and juicy skewers of ground lamb or beef, flavored with
#                 aromatic spices and herbs CONTACT Need Help ? Contact Us Our Address A108 Adam Street, New York, NY 535022 Email Us contact@example.com Call Us +1 5589 55488 55 Opening Hours Mon-Sat: 11AM - 23PM; Sunday :
#                 Closed Send Message Mealify Mealify is a restaurant landing page that offers a delicious dining
#             experience to its customers. Social Media Subscribe our Newsletter Don't miss out on our latest menu updates and exclusive offers -
#               join our newsletter today and stay up-to-date with all things
#               Mealify! Subscribe Quick Links Menu Promo About Us Contact Testimonial Our Partners Get in Touch A108 Adam Street, New York, NY 535022 contact@example.com +1 5589 55488 55

# %%
# Normalization: convert to lowercase
text_normalized = text.lower()

# Tokenization: split the text into words
tokens = word_tokenize(text_normalized)

# Lemmatization: reduce words to their base form
lemmatizer = WordNetLemmatizer()
lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]

# Remove stop words
stop_words = set(stopwords.words('english'))
filtered_tokens = [token for token in lemmatized_tokens if token not in stop_words and token.isalpha()]

# Identify unique words
unique_words = set(filtered_tokens)

unique_words
# Out:
# {'accusantium',
#  'adam',
#  'address',
#  'anderson',
#  'animi',
#  'architecto',
#  'aromatic',
#  'aspernatur',
#  'aut',
#  'autem',
#  'background',
#  'beatae',
#  'beef',
#  'beer',
#  'bison',
#  'black',
#  'book',
#  'brown',
#  'burger',
#  'call',
#  'cast',
#  'ceramic',
#  'check',
#  'chef',
#  'chicken',
#  'chip',
#  'closed',
#  'coating',
#  'consectetur',
#  'consequatur',
#  'contact',
#  'cook',
#  'corporis',
#  'crispy',
#  'crunchy',
#  'cumque',
#  'customer',
#  'delicious',
#  'deserunt',
#  'dining',
#  'dolores',
#  'dolorum',
#  'ea',
#  'email',
#  'enim',
#  'enjoy',
#  'esse',
#  'est',
#  'et',
#  'eum',
#  'eveniet',
#  'exclusive',
#  'exercitationem',
#  'experience',
#  'fed',
#  'fire',
#  'flame',
#  'flavored',
#  'flying',
#  'food',
#  'fried',
#  'frittata',
#  'fugit',
#  'gallery',
#  'get',
#  'golden',
#  'grass',
#  'grate',
#  'ground',
#  'ham',
#  'hamburger',
#  'hawaiian',
#  'healthy',
#  'help',
#  'herb',
#  'home',
#  'hour',
#  'id',
#  'ipsa',
#  'ipsum',
#  'iron',
#  'itaque',
#  'iure',
#  'jhonson',
#  'join',
#  'juicy',
#  'kebab',
#  'lamb',
#  'landing',
#  'latest',
#  'laudantium',
#  'leg',
#  'levitation',
#  'link',
#  'lyulya',
#  'master',
#  'mealify',
#  'meat',
#  'medium',
#  'menu',
#  'message',
#  'minimum',
#  'miss',
#  'modi',
#  'molestiae',
#  'need',
#  'neque',
#  'new',
#  'newsletter',
#  'nihil',
#  'ny',
#  'offer',
#  'omnis',
#  'opening',
#  'page',
#  'pariatur',
#  'partner',
#  'patissier',
#  'pie',
#  'pineapple',
#  'pizza',
#  'plate',
#  'porro',
#  'potato',
#  'proffesional',
#  'promo',
#  'quae',
#  'quaerat',
#  'quas',
#  'qui',
#  'quia',
#  'quick',
#  'quo',
#  'reiciendis',
#  'repellendus',
#  'restaurant',
#  'sapiente',
#  'sarah',
#  'sed',
#  'send',
#  'skewer',
#  'social',
#  'spice',
#  'stay',
#  'steak',
#  'street',
#  'subscribe',
#  'sunday',
#  'suscipit',
#  'table',
#  'tasty',
#  'tempore',
#  'tender',
#  'tenetur',
#  'testimonial',
#  'thing',
#  'today',
#  'touch',
#  'u',
#  'unde',
#  'update',
#  'vel',
#  'velit',
#  'vero',
#  'video',
#  'voluptas',
#  'voluptate',
#  'voluptatem',
#  'voluptates',
#  'walter',
#  'watch',
#  'white',
#  'william',
#  'york'}

# %%
len(unique_words)
# Out:
# 174

# %%
import numpy as np
np.array(unique_words).reshape(1,-1)
# Out:
# array([[{'itaque', 'velit', 'et', 'aspernatur', 'u', 'dining', 'promo', 'food', 'today', 'pie', 'nihil', 'modi', 'flying', 'architecto', 'background', 'video', 'lamb', 'jhonson', 'restaurant', 'accusantium', 'fed', 'burger', 'master', 'chef', 'landing', 'frittata', 'york', 'home', 'coating', 'quas', 'menu', 'fried', 'suscipit', 'touch', 'kebab', 'grate', 'subscribe', 'stay', 'ground', 'ceramic', 'lyulya', 'offer', 'fugit', 'spice', 'ea', 'ham', 'help', 'healthy', 'exercitationem', 'iron', 'ipsa', 'quae', 'meat', 'laudantium', 'reiciendis', 'william', 'voluptate', 'dolores', 'fire', 'newsletter', 'miss', 'need', 'vel', 'book', 'call', 'pariatur', 'gallery', 'white', 'thing', 'hamburger', 'ny', 'testimonial', 'closed', 'hawaiian', 'id', 'voluptates', 'omnis', 'quia', 'adam', 'page', 'flame', 'enjoy', 'brown', 'update', 'aromatic', 'pizza', 'autem', 'voluptas', 'juicy', 'hour', 'unde', 'email', 'beef', 'vero', 'check', 'delicious', 'esse', 'ipsum', 'flavored', 'partner', 'table', 'proffesional', 'customer', 'herb', 'link', 'consectetur', 'plate', 'crunchy', 'latest', 'get', 'sed', 'enim', 'patissier', 'animi', 'tenetur', 'levitation', 'message', 'beatae', 'voluptatem', 'exclusive', 'walter', 'minimum', 'join', 'sunday', 'aut', 'medium', 'tempore', 'leg', 'neque', 'corporis', 'deserunt', 'black', 'cumque', 'sarah', 'new', 'crispy', 'address', 'iure', 'consequatur', 'bison', 'est', 'tasty', 'quick', 'watch', 'mealify', 'grass', 'golden', 'anderson', 'skewer', 'pineapple', 'send', 'experience', 'quaerat', 'quo', 'contact', 'sapiente', 'repellendus', 'dolorum', 'tender', 'opening', 'cast', 'eum', 'beer', 'street', 'molestiae', 'chip', 'qui', 'eveniet', 'potato', 'porro', 'social', 'chicken', 'cook', 'steak'}]],
#       dtype=object)

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# Generate a word cloud image
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(" ".join(unique_words))

# Display the word cloud using matplotlib
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off') 
plt.show()
